# %%
# These lines import the Numpy modules.
import numpy as np
from datascience import *
from pandas import *
import glob

# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore', FutureWarning)
import os

# %% [markdown]
# # Graphing Meteorological Data to Find PBL Height

# %% [markdown]
# ## Load All Meteorological Files

# %%
AJet_20130717=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20130717_R0.csvout.csv')
AJet_20130910=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20130910_R0.csvout.csv')
AJet_20130912=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20130912_R0.csvout.csv')
AJet_20130918=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20130918_R0.csvout.csv')
AJet_20131029=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20131029_R1.csv')
AJet_20131118=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20131118_R0.csv')
AJet_20131126=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20131126_R0.csv')
AJet_20131205=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20131205_R0.csv')
AJet_20140213=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140213_R1.csv')
AJet_20140305=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140305_R1.csvout.csv')
AJet_20140313=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140313_R0.csvout.csv')
AJet_20140403=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140403_R0.csv')
AJet_20140424=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140424_R0.csvout.csv')
AJet_20140501=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140501_R0.csvout.csv')
AJet_20140508=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140508_R0.csvout.csv')
AJet_20140514=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140514_R0.csvout.csv')
AJet_20140519=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140519_R0.csvout.csv')
AJet_20140528=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140528_R0.csvout.csv')
AJet_20140603=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140603_R0.csvout.csv')
AJet_20140604=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140604_R0.csvout.csv')
AJet_20140610=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140610_R0.csvout.csv')
AJet_20140618=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140618_R0.csvout.csv')
AJet_20140624=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140624_R0.csvout.csv')
AJet_20140625=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140625_R0.csvout.csv')
AJet_20140627=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140627_R0.csv')
AJet_20140628=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140628_R0.csvout.csv')
AJet_20140715=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140715_R0.csvout.csv')
AJet_20140725=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140725_R0.csvout.csv')
AJet_20140729=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140729_R0.csv')
AJet_20140806=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140806_R0.csvout.csv')
AJet_20140813=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140813_R0.csvout.csv')
AJet_20140829=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140829_R0.csv')
AJet_20140829=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140829_R0.csvout.csv')
AJet_20140902=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140902_R0.csvout.csv')
AJet_20140909=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140909_R0.csvout.csv')
AJet_20140916=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140916_R0.csvout.csv')
AJet_20140922=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20140922_R0.csvout.csv')
AJet_20141002=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20141002_R0.csvout.csv')
AJet_20141024=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20141024_R0.csv')
AJet_20141106=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20141106_R0.csv')
AJet_20141110=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20141110_R0.csvout.csv')
AJet_20141125=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20141125_R0.csv')
AJet_20141210=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20141210_R0.csv')
AJet_20150318=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150318_R0.csvout.csv')
AJet_20150325=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150325_R0.csvout.csv')
AJet_20150331=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150331_R0.csv')
AJet_20150414=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150414_R0.csv')
AJet_20150424=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150424_R0.csvout.csv')
AJet_20150512=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150512_R0.csvout.csv')
AJet_20150519=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150519_R0.csvout.csv')
AJet_20150527=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150527_R0.csvout.csv')
AJet_20150602=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150602_R0.csv')
AJet_20150611=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150611_R0.csvout.csv')
AJet_20150629=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150629_R0.csvout.csv')
AJet_20150701=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150701_R0.csv')
AJet_20150722=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150722_R0.csv')
AJet_20150729=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150729_R0.csvout.csv')
AJet_20150805=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150805_R0.csv')
AJet_20150819=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150819_R0.csvout.csv')
AJet_20150924=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20150924_R0.csvout.csv')
AJet_20151001=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20151001_R0.csv')
AJet_20151007=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20151007_R0.csvout.csv')
AJet_20151022=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20151022_R0.csvout.csv')
AJet_20151117=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20151117_R0.csvout.csv')
AJet_20151204=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20151204_R0.csv')
AJet_20151209=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20151209_R0.csvout.csv')
AJet_20151215=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20151215_R0.csv')
AJet_20160108=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20160108_R0.csvout.csv')
AJet_20160112=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20160112_R0.csvout.csv')
AJet_20160310=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20160310_R0.csvout.csv')
AJet_20160317=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20160317_R0.csvout.csv')
AJet_20160323=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20160323_R0.csvout.csv')
AJet_20160330=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20160330_R0.csvout.csv')
AJet_20160419=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20160419_R0.csv')
AJet_20160426=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20160426_R0.csvout.csv')
AJet_20160504=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20160504_R0.csv')
AJet_20160519=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20160519_R0.csvout.csv')
AJet_20160603=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20160603_R0.csvout.csv')
AJet_20160615=Table.read_table('complete_ajax_data\metdata\MMS-MetData_AJet_20160615_R0.csvout.csv')

# %%
def profile(flight):
    flight.scatter('G_ALT','T')
    flight.scatter('G_ALT','P')

# %%
profile(AJet_20130717)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-82828325c667> in <module>()
# ----> 1 profile(AJet_20130717)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('TIME_UTC\t P\t T\t TAS\t U\t V\t W\t TEDR\t REYN\t G_LAT\t G_LONG\t G_ALT\t POT\t ROLL\t HDG\t PITCH                                                                                                                   ',)

# %%
profile(AJet_20130910)

# %%
profile(AJet_20130912)

# %%
profile(AJet_20130918)

# %%
profile(AJet_20131029)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-824820061917> in <module>()
# ----> 1 profile(AJet_20131029)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R1: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20131118)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-498a140ac1d0> in <module>()
# ----> 1 profile(AJet_20131118)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('REVISION: R0                                                                                                                                                                                            ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20131126)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-3a9fc734bc50> in <module>()
# ----> 1 profile(AJet_20131126)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20131205)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-c211635d76a8> in <module>()
# ----> 1 profile(AJet_20131205)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20140213)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-c723e8d601f6> in <module>()
# ----> 1 profile(AJet_20140213)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R1: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20140305)

# %%
profile(AJet_20140313)

# %%
profile(AJet_20140403)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-7ef4e94bc738> in <module>()
# ----> 1 profile(AJet_20140403)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20140424)

# %%
profile(AJet_20140501)

# %%
profile(AJet_20140508)

# %%
profile(AJet_20140514)

# %%
profile(AJet_20140519)

# %%
profile(AJet_20140528)

# %%
profile(AJet_20140603)

# %%
profile(AJet_20140604)

# %%
profile(AJet_20140610)

# %%
profile(AJet_20140618)

# %%
profile(AJet_20140624)

# %%
profile(AJet_20140625)

# %%
profile(AJet_20140627)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-46230691cd51> in <module>()
# ----> 1 profile(AJet_20140627)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20140628)

# %%
profile(AJet_20140715)

# %%
profile(AJet_20140725)

# %%
profile(AJet_20140729)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-e7e32641cbd7> in <module>()
# ----> 1 profile(AJet_20140729)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20140806)

# %%
profile(AJet_20140813)

# %%
profile(AJet_20140829)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-8d85e62aa55b> in <module>()
# ----> 1 profile(AJet_20140829)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20140829)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-8d85e62aa55b> in <module>()
# ----> 1 profile(AJet_20140829)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20140902)

# %%
profile(AJet_20140909)

# %%
profile(AJet_20140916)

# %%
profile(AJet_20140922)

# %%
profile(AJet_20141002)

# %%
profile(AJet_20141024)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-4a2ff522f7b4> in <module>()
# ----> 1 profile(AJet_20141024)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20141106)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-2bf517649963> in <module>()
# ----> 1 profile(AJet_20141106)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20141110)

# %%
profile(AJet_20141125)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-ee7df02057cb> in <module>()
# ----> 1 profile(AJet_20141125)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20141210)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-fb9e670ddcf5> in <module>()
# ----> 1 profile(AJet_20141210)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20150318)

# %%
profile(AJet_20150325)

# %%
profile(AJet_20150331)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-2454652023ea> in <module>()
# ----> 1 profile(AJet_20150331)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20150414)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-c340a62316ab> in <module>()
# ----> 1 profile(AJet_20150414)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20150424)

# %%
profile(AJet_20150512)

# %%
profile(AJet_20150519)

# %%
profile(AJet_20150527)

# %%
profile(AJet_20150602)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-098da43fc355> in <module>()
# ----> 1 profile(AJet_20150602)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20150611)

# %%
profile(AJet_20150629)

# %%
profile(AJet_20150701)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-d48d2666bd05> in <module>()
# ----> 1 profile(AJet_20150701)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('REVISION: R0                                                                                                                                                                                            ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20150722)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-d8bb30297008> in <module>()
# ----> 1 profile(AJet_20150722)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20150729)

# %%
profile(AJet_20150805)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-9577a077ddc5> in <module>()
# ----> 1 profile(AJet_20150805)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20150819)

# %%
profile(AJet_20150924)

# %%
profile(AJet_20151001)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-1440e6be1d27> in <module>()
# ----> 1 profile(AJet_20151001)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20151007)

# %%
profile(AJet_20151022)

# %%
profile(AJet_20151117)

# %%
profile(AJet_20151204)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-35e749d53674> in <module>()
# ----> 1 profile(AJet_20151204)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20151209)

# %%
profile(AJet_20151215)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-7285cba9d869> in <module>()
# ----> 1 profile(AJet_20151215)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('REVISION: R0                                                                                                                                                                                            ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20160108)

# %%
profile(AJet_20160112)

# %%
profile(AJet_20160310)

# %%
profile(AJet_20160317)

# %%
profile(AJet_20160323)

# %%
profile(AJet_20160330)

# %%
profile(AJet_20160419)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-401656491968> in <module>()
# ----> 1 profile(AJet_20160419)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20160426)

# %%
profile(AJet_20160504)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-9606740575f9> in <module>()
# ----> 1 profile(AJet_20160504)
#
# <ipython-input-48-b57e78b0cb57> in profile(flight)
#       1 def profile(flight):
# ----> 2     flight.scatter('G_ALT','T')
#       3     flight.scatter('G_ALT','P')
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, **vargs)
#    1794         options.update(vargs)
#    1795
# -> 1796         x_data, y_labels =  self._split_column_and_labels(column_for_x)
#    1797         if select is not None:
#    1798             y_labels = self._as_labels(select)
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _split_column_and_labels(self, column_or_label)
#    1860     def _split_column_and_labels(self, column_or_label):
#    1861         """Return the specified column and labels of other columns."""
# -> 1862         column = None if column_or_label is None else self._get_column(column_or_label)
#    1863         labels = [label for i, label in enumerate(self.labels) if column_or_label not in (i, label)]
#    1864         return column, labels
#
# C:\Users\graheja\AppData\Local\Continuum\Anaconda3\lib\site-packages\datascience\tables.py in _get_column(self, column_or_label)
#    1087             return self[c]
#    1088         elif isinstance(c, str):
# -> 1089             raise ValueError('label "{}" not in labels {}'.format(c, self.labels))
#    1090         else:
#    1091             assert len(c) == self.num_rows, 'column length mismatch'
#
# ValueError: label "G_ALT" not in labels ('R0: PRELIMINARY DATA                                                                                                                                                                                    ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15')

# %%
profile(AJet_20160519)

# %%
profile(AJet_20160603)

# %%
profile(AJet_20160615)
